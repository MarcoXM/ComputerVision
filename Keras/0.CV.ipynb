# %% [markdown]
# # 数据生成
#
# ## 这个数据集 是随机生成的一个dataset.
# ## 用来讲解CNN 是如何分类图片
#
# ![image.png](attachment:image.png)

# %%
import keras
import numpy as np
import random



## 

number_of_samples=2500; # 我们这里产生250张图片
nb_samples=number_of_samples;
frame_row=32; # 我们横着像素是 32个pixels
frame_col=32; # 竖着也是 32个pixel ~ 没错正方形会更好！
channels=3; # 什么事channel ,这就是 三种颜色啊~ RGB ,问题来了，如果是灰色呢？ 我们应该选什么呢？

#### ！！！1 就好了


data= np.random.random((2500,frame_row,frame_col,channels)) # 这个就是data的生成啊~
#  维度是 2500，3通道，横，竖 各32pixel



label=np.array([np.random.randint(0,2) for i in range(2500)]).reshape(-1,1) # 随机生成对应的  labels ， 
#reshape的话！把他变成 竖的结构！
np.random.seed(224)
## 上面的数据就 X 是tensor ，y还不是哈！
# Out:
# Using TensorFlow backend.
# /anaconda3/envs/tf/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.7
#   return f(*args, **kwds)

# %%
x_train,y_train = data[:2000],label[:2000]
x_test,y_test = data[2000:],label[2000:]

# %% [markdown]
# # Input

# %%
y_train.shape
# Out:
# (2000, 1)

# %% [markdown]
# # 模型搭建

# %%
from keras.models import Sequential
from keras.layers import Activation,Conv2D,MaxPooling2D,Flatten, Dense, Dropout
from keras import losses

model = Sequential()

model.add(Conv2D(16,(3,3),padding = 'same',input_shape = (32,32,3),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(32,(3,3),padding = 'same',activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())
model.add(Dense(64*4*4))
model.add(Activation('relu'))
#model.add(Dropout(0.3))
model.add(Dense(2))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 1,075,234
# Trainable params: 1,075,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 练习~

# %%
from keras.utils import np_utils
# ont_hot
y_train = np_utils.to_categorical(y_train,2)
y_test = np_utils.to_categorical(y_test,2)

# %%
model.compile(loss = 'categorical_crossentropy',optimizer='adam',metrics = ['accuracy'])

from keras.callbacks import ModelCheckpoint

cp = ModelCheckpoint(filepath='CV.weights.best.hdf5',verbose=1,save_best_only=True)

hist = model.fit(x_train,y_train,epochs=50,batch_size=32,verbose=1,validation_split=0.2,shuffle=True,callbacks=[cp])
# Out:
# WARNING:tensorflow:From /anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1600 samples, validate on 400 samples
# Epoch 1/50
# 1600/1600 [==============================] - 6s 3ms/step - loss: 0.7636 - acc: 0.4919 - val_loss: 0.6933 - val_acc: 0.5050
#
# Epoch 00001: val_loss improved from inf to 0.69334, saving model to CV.weights.best.hdf5
# Epoch 2/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6924 - acc: 0.4719 - val_loss: 0.6974 - val_acc: 0.4950
#
# Epoch 00002: val_loss did not improve from 0.69334
# Epoch 3/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6955 - acc: 0.5231 - val_loss: 0.6932 - val_acc: 0.4950
#
# Epoch 00003: val_loss improved from 0.69334 to 0.69317, saving model to CV.weights.best.hdf5
# Epoch 4/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6933 - acc: 0.5000 - val_loss: 0.6932 - val_acc: 0.4950
#
# Epoch 00004: val_loss did not improve from 0.69317
# Epoch 5/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6933 - acc: 0.4944 - val_loss: 0.6944 - val_acc: 0.5050
#
# Epoch 00005: val_loss did not improve from 0.69317
# Epoch 6/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6936 - acc: 0.5125 - val_loss: 0.6935 - val_acc: 0.4950
#
# Epoch 00006: val_loss did not improve from 0.69317
# Epoch 7/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6923 - acc: 0.4806 - val_loss: 0.6945 - val_acc: 0.5050
#
# Epoch 00007: val_loss did not improve from 0.69317
# Epoch 8/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6910 - acc: 0.4581 - val_loss: 0.6978 - val_acc: 0.4950
#
# Epoch 00008: val_loss did not improve from 0.69317
# Epoch 9/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6892 - acc: 0.4800 - val_loss: 0.6976 - val_acc: 0.4975
#
# Epoch 00009: val_loss did not improve from 0.69317
# Epoch 10/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6909 - acc: 0.4400 - val_loss: 0.6943 - val_acc: 0.5300
#
# Epoch 00010: val_loss did not improve from 0.69317
# Epoch 11/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6943 - acc: 0.4944 - val_loss: 0.6959 - val_acc: 0.5050
#
# Epoch 00011: val_loss did not improve from 0.69317
# Epoch 12/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6871 - acc: 0.4606 - val_loss: 0.6981 - val_acc: 0.5250
#
# Epoch 00012: val_loss did not improve from 0.69317
# Epoch 13/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6684 - acc: 0.3937 - val_loss: 0.7096 - val_acc: 0.5575
#
# Epoch 00013: val_loss did not improve from 0.69317
# Epoch 14/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6545 - acc: 0.3744 - val_loss: 0.7420 - val_acc: 0.5250
#
# Epoch 00014: val_loss did not improve from 0.69317
# Epoch 15/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6373 - acc: 0.3819 - val_loss: 0.7991 - val_acc: 0.5050
#
# Epoch 00015: val_loss did not improve from 0.69317
# Epoch 16/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6585 - acc: 0.3800 - val_loss: 0.7653 - val_acc: 0.5400
#
# Epoch 00016: val_loss did not improve from 0.69317
# Epoch 17/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6104 - acc: 0.3244 - val_loss: 0.7260 - val_acc: 0.5050
#
# Epoch 00017: val_loss did not improve from 0.69317
# Epoch 18/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6137 - acc: 0.2863 - val_loss: 0.7948 - val_acc: 0.5000
#
# Epoch 00018: val_loss did not improve from 0.69317
# Epoch 19/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.7685 - acc: 0.4131 - val_loss: 0.7010 - val_acc: 0.4950
#
# Epoch 00019: val_loss did not improve from 0.69317
# Epoch 20/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6824 - acc: 0.4319 - val_loss: 0.6984 - val_acc: 0.5250
#
# Epoch 00020: val_loss did not improve from 0.69317
# Epoch 21/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6671 - acc: 0.4050 - val_loss: 0.7132 - val_acc: 0.5025
#
# Epoch 00021: val_loss did not improve from 0.69317
# Epoch 22/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6079 - acc: 0.3169 - val_loss: 0.7548 - val_acc: 0.5125
#
# Epoch 00022: val_loss did not improve from 0.69317
# Epoch 23/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6938 - acc: 0.3713 - val_loss: 0.7018 - val_acc: 0.5175
#
# Epoch 00023: val_loss did not improve from 0.69317
# Epoch 24/50
# 1600/1600 [==============================] - 7s 4ms/step - loss: 0.6340 - acc: 0.3331 - val_loss: 0.7662 - val_acc: 0.5175
#
# Epoch 00024: val_loss did not improve from 0.69317
# Epoch 25/50
# 1600/1600 [==============================] - 6s 3ms/step - loss: 0.5952 - acc: 0.2869 - val_loss: 0.7291 - val_acc: 0.5300
#
# Epoch 00025: val_loss did not improve from 0.69317
# Epoch 26/50
# 1600/1600 [==============================] - 6s 3ms/step - loss: 0.5526 - acc: 0.2737 - val_loss: 1.0782 - val_acc: 0.5025
#
# Epoch 00026: val_loss did not improve from 0.69317
# Epoch 27/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.5807 - acc: 0.2356 - val_loss: 1.2430 - val_acc: 0.5300
#
# Epoch 00027: val_loss did not improve from 0.69317
# Epoch 28/50
# 1600/1600 [==============================] - 4s 3ms/step - loss: 0.6148 - acc: 0.2531 - val_loss: 1.3681 - val_acc: 0.5400
#
# Epoch 00028: val_loss did not improve from 0.69317
# Epoch 29/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.5108 - acc: 0.2056 - val_loss: 2.4333 - val_acc: 0.5300
#
# Epoch 00029: val_loss did not improve from 0.69317
# Epoch 30/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5254 - acc: 0.1931 - val_loss: 1.2335 - val_acc: 0.5225
#
# Epoch 00030: val_loss did not improve from 0.69317
# Epoch 31/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6149 - acc: 0.2369 - val_loss: 0.7668 - val_acc: 0.5250
#
# Epoch 00031: val_loss did not improve from 0.69317
# Epoch 32/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.5275 - acc: 0.2238 - val_loss: 1.1495 - val_acc: 0.5550
#
# Epoch 00032: val_loss did not improve from 0.69317
# Epoch 33/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4173 - acc: 0.1825 - val_loss: 3.1760 - val_acc: 0.5425
#
# Epoch 00033: val_loss did not improve from 0.69317
# Epoch 34/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4548 - acc: 0.1619 - val_loss: 0.8109 - val_acc: 0.4950
#
# Epoch 00034: val_loss did not improve from 0.69317
# Epoch 35/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6597 - acc: 0.3744 - val_loss: 0.7020 - val_acc: 0.5050
#
# Epoch 00035: val_loss did not improve from 0.69317
# Epoch 36/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6429 - acc: 0.3600 - val_loss: 0.7724 - val_acc: 0.5375
#
# Epoch 00036: val_loss did not improve from 0.69317
# Epoch 37/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6538 - acc: 0.3738 - val_loss: 0.7072 - val_acc: 0.5000
#
# Epoch 00037: val_loss did not improve from 0.69317
# Epoch 38/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6376 - acc: 0.3050 - val_loss: 0.7266 - val_acc: 0.5475
#
# Epoch 00038: val_loss did not improve from 0.69317
# Epoch 39/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6066 - acc: 0.3069 - val_loss: 0.9519 - val_acc: 0.5300
#
# Epoch 00039: val_loss did not improve from 0.69317
# Epoch 40/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.5713 - acc: 0.2956 - val_loss: 1.2857 - val_acc: 0.5375
#
# Epoch 00040: val_loss did not improve from 0.69317
# Epoch 41/50
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.5685 - acc: 0.2744 - val_loss: 0.9157 - val_acc: 0.5375
#
# Epoch 00041: val_loss did not improve from 0.69317
# Epoch 42/50
# 1600/1600 [==============================] - 4s 3ms/step - loss: 0.5060 - acc: 0.2500 - val_loss: 1.4088 - val_acc: 0.5425
#
# Epoch 00042: val_loss did not improve from 0.69317
# Epoch 43/50
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.5047 - acc: 0.2219 - val_loss: 0.8795 - val_acc: 0.5575
#
# Epoch 00043: val_loss did not improve from 0.69317
# Epoch 44/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4695 - acc: 0.2056 - val_loss: 1.8530 - val_acc: 0.5425
#
# Epoch 00044: val_loss did not improve from 0.69317
# Epoch 45/50
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.4872 - acc: 0.2319 - val_loss: 0.7114 - val_acc: 0.5375
#
# Epoch 00045: val_loss did not improve from 0.69317
# Epoch 46/50
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6488 - acc: 0.3387 - val_loss: 0.7256 - val_acc: 0.5250
#
# Epoch 00046: val_loss did not improve from 0.69317
# Epoch 47/50
# 1600/1600 [==============================] - 6s 4ms/step - loss: 0.6446 - acc: 0.3531 - val_loss: 0.7433 - val_acc: 0.5325
#
# Epoch 00047: val_loss did not improve from 0.69317
# Epoch 48/50
# 1600/1600 [==============================] - 6s 4ms/step - loss: 0.6660 - acc: 0.3744 - val_loss: 0.7053 - val_acc: 0.5225
#
# Epoch 00048: val_loss did not improve from 0.69317
# Epoch 49/50
# 1600/1600 [==============================] - 4s 3ms/step - loss: 0.6451 - acc: 0.3287 - val_loss: 0.7172 - val_acc: 0.5250
#
# Epoch 00049: val_loss did not improve from 0.69317
# Epoch 50/50
# 1600/1600 [==============================] - 5s 3ms/step - loss: 0.6105 - acc: 0.3069 - val_loss: 0.7189 - val_acc: 0.5375
#
# Epoch 00050: val_loss did not improve from 0.69317

# %%
model.load_weights('CV.weights.best.hdf5')

# %%
y_pred = model.predict_classes(x_test)

# %%
model.evaluate(x_test,y_test)[1]
# Out:
# 500/500 [==============================] - 0s 616us/step
# 0.48800000047683717
